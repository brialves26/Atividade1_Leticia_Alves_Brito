# %% [markdown]
# # Notebook_Leticia_Alves_Brito
#
# **Descrição da atividade:**
# Estou achando a atividade **interessante** até aqui. É uma boa forma de aprender a usar *Markdown* dentro do Jupyter Notebook e explorar diferentes formas de formatação de texto.
#
# Também é legal poder escrever trechos no estilo de código, como por exemplo:
# `print("Olá, mundo!")`

# %%
import pandas as pd

# %%
file_path = r"C:\Users\Windows 11\Downloads\Jupyter_notebook_Leticia_Alves_Brito\default_of_credit_card_clients__courseware_version_1_21_19.xls"

# %%
df = pd.read_excel("default_of_credit_card_clients__courseware_version_1_21_19.xls")

# %%
num_columns = df.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 25

# %%
num_rows = df.shape[0]
print("Number of samples (rows):", num_rows)
# Out:
# Number of samples (rows): 30000

# %%
print(df.dtypes)
# Out:
# ID                            object
# LIMIT_BAL                      int64
# SEX                            int64
# EDUCATION                      int64
# MARRIAGE                       int64
# AGE                            int64
# PAY_1                         object
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month     int64
# dtype: object

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
print("Numeric features:", numeric_columns)
# Out:
# Numeric features: Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_2', 'PAY_3',
#        'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
#        'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
print("Categorical features:", categorical_columns)
# Out:
# Categorical features: Index(['ID', 'PAY_1'], dtype='object')

# %%
for col in categorical_columns:
    print(f"{col}: {df[col].unique()[:10]}")
# Out:
# ID: ['798fc410-45c1' '8a8c8f3b-8eb4' '85698822-43f5' '0737c11b-be42'
#  '3b7f77cc-dbc0' 'ceae2946-47e4' 'd3b8ce26-9c89' 'd6e1911b-54d0'
#  '8421d3b3-2b54' '62a2fd79-cd90']
# PAY_1: [2 -1 0 -2 1 'Not available' 3 4 8 7]

# %%
df[numeric_columns].describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
